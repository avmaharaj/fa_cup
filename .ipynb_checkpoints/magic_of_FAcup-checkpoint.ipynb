# %% [markdown]
# # Is there still magic in the FA cup?
#
# *An attempt to study whether the FA cup still retains its magic, i.e. whether or not weaker/lower division teams can make it to the latter stages of the cup. This project was initiated to investigate the common complaint of football "pundits" - that the FA cup is no longer magical. While it's hard to know what is meant by such a complaint, one quantitative metric is the number of lower division teams upsetting high division teams. We also investigate goals scored by lower division teams, and the proportion of lower division teams making it through to the later rounds of the competition.*

# %%
#As usual import some modules as import the dataset
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

#import the data
facup = pd.read_csv("data/facup.csv")
allgames = pd.read_csv("data/engsoccerdata2.csv")

#A utility function for calculating moving averages
def movingaverage(interval, window_size):
    window= np.ones(int(window_size))/float(window_size)
    return np.convolve(interval, window, 'same')

#Look at some of the data
facup.head(5)
# Out:
#          date  Season                 home              visitor   FT  hgoal  \
# 0  1871-11-11    1871               Barnes        Civil Service  2-0      2
# 1  1871-11-11    1871              Hitchin  Crystal Palace 1861  0-0      0
# 2  1871-11-11    1871    Maidenhead United               Marlow  2-0      2
# 3  1871-11-11    1871           Upton Park       Clapham Rovers  0-3      0
# 4  1871-12-16    1871  Crystal Palace 1861    Maidenhead United  3-0      3
#
#    vgoal round      tie  aet  pen pens  hp  vp                   Venue  \
# 0      0     1  initial  NaN  NaN  NaN NaN NaN                     NaN
# 1      0     1  initial  NaN  NaN  NaN NaN NaN      Top Field, Hitchin
# 2      0     1  initial  NaN  NaN  NaN NaN NaN   York Road, Maidenhead
# 3      3     1  initial  NaN  NaN  NaN NaN NaN   West Ham Park, London
# 4      0     2  initial  NaN  NaN  NaN NaN NaN  Crystal Palace, London
#
#   attendance nonmatch                           notes neutral
# 0      1,200      NaN                             NaN     NaN
# 1        750      NaN  No replay, both teams progress     NaN
# 2      1,287      NaN                             NaN     NaN
# 3      1,500      NaN                             NaN     NaN
# 4        NaN      NaN                             NaN     NaN

# %% [markdown]
# # Historical trend of replays (proxy of competitiveness?)
# **First group by types of games**

# %%
#First copy the data frame
facup_mod = facup.copy()

#Replace all instances of replay with just a single demarcation
facup_mod.replace('replay[1234]','replay',inplace = True,regex = True)

#Add a couple new columns to show whether a game is a tie or a replay
season_tie = pd.crosstab(index = facup_mod["Season"], columns = facup_mod["tie"])

#Finally print some data to show what we've done
print season_tie.tail(4)
facup
# Out:
# tie     initial  leg1  leg2  none  replay
# Season
# 2011        123     0     0     0      28
# 2012        123     0     0     0      33
# 2013        123     0     0     0      18
# 2014        123     0     0     0      30
#              date  Season                    home                 visitor  \
# 0      1871-11-11    1871                  Barnes           Civil Service
# 1      1871-11-11    1871                 Hitchin     Crystal Palace 1861
# 2      1871-11-11    1871       Maidenhead United                  Marlow
# 3      1871-11-11    1871              Upton Park          Clapham Rovers
# 4      1871-12-16    1871     Crystal Palace 1861       Maidenhead United
# 5      1871-12-16    1871               Wanderers          Clapham Rovers
# 6      1871-12-23    1871                  Barnes      Hampstead Heathens
# 7      1872-01-06    1871      Hampstead Heathens                  Barnes
# 8      1872-01-10    1871                 Hitchin         Royal Engineers
# 9      1872-01-20    1871               Wanderers     Crystal Palace 1861
# 10     1872-01-27    1871         Royal Engineers      Hampstead Heathens
# 11     1872-02-17    1871     Crystal Palace 1861         Royal Engineers
# 12     1872-03-05    1871             Queens Park               Wanderers
# 13     1872-03-09    1871         Royal Engineers     Crystal Palace 1861
# 14     1872-03-16    1871               Wanderers         Royal Engineers
# 15            NaN    1871         Royal Engineers          Reigate Priory
# 16            NaN    1871               Wanderers         Harrow Chequers
# 17            NaN    1871      Hampstead Heathens                     NaN
# 18            NaN    1871             Queens Park        Donington School
# 19            NaN    1871             Queens Park        Donington School
# 20            NaN    1871             Queens Park                     NaN
# 21            NaN    1871               Wanderers             Queens Park
# 22     1872-10-19    1872                  Barnes           South Norwood
# 23     1872-10-26    1872           Civil Service         Royal Engineers
# 24     1872-10-26    1872          Crystal Palace       Oxford University
# 25     1872-10-26    1872       Maidenhead United                  Marlow
# 26     1872-10-26    1872          Reigate Priory       Windsor Home Park
# 27     1872-10-26    1872              Upton Park       1st Surrey Rifles
# 28     1872-11-23    1872       1st Surrey Rifles       Maidenhead United
# 29     1872-11-23    1872          Clapham Rovers       Oxford University
# ...           ...     ...                     ...                     ...
# 16446  2014-11-08    2014               Port Vale      Milton Keynes Dons
# 16447  2014-11-08    2014         Plymouth Argyle               AFC Fylde
# 16448  2014-11-08    2014                Barnsley           Burton Albion
# 16449  2014-11-08    2014       Hartlepool United    East Thurrock United
# 16450  2014-11-08    2014         Oldham Athletic           Leyton Orient
# 16451  2014-11-09    2014            Halifax Town           Bradford City
# 16452  2014-11-09    2014          Braintree Town            Chesterfield
# 16453  2014-11-09    2014              Portsmouth          Aldershot Town
# 16454  2014-11-09    2014       Stevenage Borough        Maidstone United
# 16455  2014-11-09    2014                 Wrexham                  Woking
# 16456  2014-11-09    2014           Coventry City          Worcester City
# 16457  2014-11-09    2014          Blyth Spartans              Altrincham
# 16458  2014-11-09    2014     Forest Green Rovers       Scunthorpe United
# 16459  2014-11-09    2014         Gosport Borough       Colchester United
# 16460  2014-11-09    2014           Norton United               Gateshead
# 16461  2014-11-09    2014            Notts County              Accrington
# 16462  2014-11-10    2014  Havant & Waterlooville       Preston North End
# 16463  2014-11-18    2014          Mansfield Town         Concord Rangers
# 16464  2014-11-18    2014       Weston-super-Mare        Doncaster Rovers
# 16465  2014-11-18    2014           AFC Wimbledon               York City
# 16466  2014-11-18    2014         Shrewsbury Town                 Walsall
# 16467  2014-11-18    2014              Accrington            Notts County
# 16468  2014-11-18    2014      AFC Telford United        Basingstoke Town
# 16469  2014-11-18    2014               Southport  Dagenham and Redbridge
# 16470  2014-11-18    2014        Sheffield United         Crewe Alexandra
# 16471  2014-11-18    2014                Rochdale        Northampton Town
# 16472  2014-11-19    2014          Aldershot Town              Portsmouth
# 16473  2014-11-20    2014        Maidstone United       Stevenage Borough
# 16474  2014-11-25    2014         Concord Rangers          Mansfield Town
# 16475  2015-05-30    2014                 Arsenal             Aston Villa
#
#         FT  hgoal  vgoal round      tie  aet  pen pens  hp  vp  \
# 0      2-0      2      0     1  initial  NaN  NaN  NaN NaN NaN
# 1      0-0      0      0     1  initial  NaN  NaN  NaN NaN NaN
# 2      2-0      2      0     1  initial  NaN  NaN  NaN NaN NaN
# 3      0-3      0      3     1  initial  NaN  NaN  NaN NaN NaN
# 4      3-0      3      0     2  initial  NaN  NaN  NaN NaN NaN
# 5      3-1      3      1     2  initial  NaN  NaN  NaN NaN NaN
# 6      1-1      1      1     2  initial  NaN  NaN  NaN NaN NaN
# 7      1-0      1      0     2   replay  NaN  NaN  NaN NaN NaN
# 8      0-5      0      5     2  initial  NaN  NaN  NaN NaN NaN
# 9      0-0      0      0     3  initial  NaN  NaN  NaN NaN NaN
# 10     3-0      3      0     3  initial  NaN  NaN  NaN NaN NaN
# 11     0-0      0      0     s  initial  NaN  NaN  NaN NaN NaN
# 12     0-0      0      0     s  initial  NaN  NaN  NaN NaN NaN
# 13     3-0      3      0     s   replay  NaN  NaN  NaN NaN NaN
# 14     1-0      1      0     f  initial  NaN  NaN  NaN NaN NaN
# 15     NaN    NaN    NaN     1  initial  NaN  NaN  NaN NaN NaN
# 16     NaN    NaN    NaN     1  initial  NaN  NaN  NaN NaN NaN
# 17     NaN    NaN    NaN     1     none  NaN  NaN  NaN NaN NaN
# 18     NaN    NaN    NaN     1     none  NaN  NaN  NaN NaN NaN
# 19     NaN    NaN    NaN     2  initial  NaN  NaN  NaN NaN NaN
# 20     NaN    NaN    NaN     3     none  NaN  NaN  NaN NaN NaN
# 21     NaN    NaN    NaN     s  initial  NaN  NaN  NaN NaN NaN
# 22     0-1      0      1     1  initial  NaN  NaN  NaN NaN NaN
# 23     0-3      0      3     1  initial  NaN  NaN  NaN NaN NaN
# 24     2-3      2      3     1  initial  NaN  NaN  NaN NaN NaN
# 25     1-0      1      0     1  initial  NaN  NaN  NaN NaN NaN
# 26     2-4      2      4     1  initial  NaN  NaN  NaN NaN NaN
# 27     0-2      0      2     1  initial  NaN  NaN  NaN NaN NaN
# 28     0-3      0      3     2  initial  NaN  NaN  NaN NaN NaN
# 29     0-3      0      3     2  initial  NaN  NaN  NaN NaN NaN
# ...    ...    ...    ...   ...      ...  ...  ...  ...  ..  ..
# 16446  3-4      3      4     1  initial  NaN  NaN  NaN NaN NaN
# 16447  2-0      2      0     1  initial  NaN  NaN  NaN NaN NaN
# 16448  5-0      5      0     1  initial  NaN  NaN  NaN NaN NaN
# 16449  2-0      2      0     1  initial  NaN  NaN  NaN NaN NaN
# 16450  1-0      1      0     1  initial  NaN  NaN  NaN NaN NaN
# 16451  1-2      1      2     1  initial  NaN  NaN  NaN NaN NaN
# 16452  0-6      0      6     1  initial  NaN  NaN  NaN NaN NaN
# 16453  2-2      2      2     1  initial  NaN  NaN  NaN NaN NaN
# 16454  0-0      0      0     1  initial  NaN  NaN  NaN NaN NaN
# 16455  3-0      3      0     1  initial  NaN  NaN  NaN NaN NaN
# 16456  1-2      1      2     1  initial  NaN  NaN  NaN NaN NaN
# 16457  4-1      4      1     1  initial  NaN  NaN  NaN NaN NaN
# 16458  0-2      0      2     1  initial  NaN  NaN  NaN NaN NaN
# 16459  3-6      3      6     1  initial  NaN  NaN  NaN NaN NaN
# 16460  0-4      0      4     1  initial  NaN  NaN  NaN NaN NaN
# 16461  0-0      0      0     1  initial  NaN  NaN  NaN NaN NaN
# 16462  0-3      0      3     1  initial  NaN  NaN  NaN NaN NaN
# 16463  1-1      1      1     1  initial  NaN  NaN  NaN NaN NaN
# 16464  1-4      1      4     1  initial  NaN  NaN  NaN NaN NaN
# 16465  3-1      3      1     1   replay  NaN  NaN  NaN NaN NaN
# 16466  1-0      1      0     1   replay  NaN  NaN  NaN NaN NaN
# 16467  2-1      2      1     1   replay  NaN  NaN  NaN NaN NaN
# 16468  2-1      2      1     1   replay  NaN  NaN  NaN NaN NaN
# 16469  2-0      2      0     1   replay  NaN  NaN  NaN NaN NaN
# 16470  2-0      2      0     1   replay  NaN  NaN  NaN NaN NaN
# 16471  2-1      2      1     1   replay  NaN  NaN  NaN NaN NaN
# 16472  1-0      1      0     1   replay  NaN  NaN  NaN NaN NaN
# 16473  2-1      2      1     1   replay  NaN  NaN  NaN NaN NaN
# 16474  0-1      0      1     1   replay  NaN  NaN  NaN NaN NaN
# 16475  4-0      4      0     f  initial  NaN  NaN  NaN NaN NaN
#
#                          Venue attendance    nonmatch  \
# 0                          NaN      1,200         NaN
# 1           Top Field, Hitchin        750         NaN
# 2        York Road, Maidenhead      1,287         NaN
# 3        West Ham Park, London      1,500         NaN
# 4       Crystal Palace, London        NaN         NaN
# 5                          NaN      2,000         NaN
# 6               Barnes, London        NaN         NaN
# 7                          NaN        600         NaN
# 8                          NaN        750         NaN
# 9       Clapham Common, London        NaN         NaN
# 10                         NaN        NaN         NaN
# 11     Kennington Oval, London      2,000         NaN
# 12     Kennington Oval, London      2,000         NaN
# 13     Kennington Oval, London      2,000         NaN
# 14     Kennington Oval, London      2,000         NaN
# 15                         NaN        NaN    Walkover
# 16                         NaN        NaN    Walkover
# 17                         NaN        NaN         Bye
# 18                         NaN        NaN  Not played
# 19                         NaN        NaN    Walkover
# 20                         NaN        NaN         Bye
# 21                         NaN        NaN    Walkover
# 22                         NaN        NaN         NaN
# 23                         NaN        NaN         NaN
# 24                         NaN        NaN         NaN
# 25                         NaN        NaN         NaN
# 26                         NaN        NaN         NaN
# 27                         NaN        NaN         NaN
# 28                         NaN        NaN         NaN
# 29                         NaN        NaN         NaN
# ...                        ...        ...         ...
# 16446                      NaN        NaN         NaN
# 16447                      NaN        NaN         NaN
# 16448                      NaN        NaN         NaN
# 16449                      NaN        NaN         NaN
# 16450                      NaN        NaN         NaN
# 16451                      NaN        NaN         NaN
# 16452                      NaN        NaN         NaN
# 16453                      NaN        NaN         NaN
# 16454                      NaN        NaN         NaN
# 16455                      NaN        NaN         NaN
# 16456                      NaN        NaN         NaN
# 16457                      NaN        NaN         NaN
# 16458                      NaN        NaN         NaN
# 16459                      NaN        NaN         NaN
# 16460                      NaN        NaN         NaN
# 16461                      NaN        NaN         NaN
# 16462                      NaN        NaN         NaN
# 16463                      NaN        NaN         NaN
# 16464                      NaN        NaN         NaN
# 16465                      NaN        NaN         NaN
# 16466                      NaN        NaN         NaN
# 16467                      NaN        NaN         NaN
# 16468                      NaN        NaN         NaN
# 16469                      NaN        NaN         NaN
# 16470                      NaN        NaN         NaN
# 16471                      NaN        NaN         NaN
# 16472                      NaN        NaN         NaN
# 16473                      NaN        NaN         NaN
# 16474                      NaN        NaN         NaN
# 16475    Wembley (new), London     89,283         NaN
#
#                                 notes neutral
# 0                                 NaN     NaN
# 1      No replay, both teams progress     NaN
# 2                                 NaN     NaN
# 3                                 NaN     NaN
# 4                                 NaN     NaN
# 5                                 NaN     NaN
# 6                                 NaN     NaN
# 7                                 NaN     NaN
# 8                                 NaN     NaN
# 9      No replay, both teams progress     NaN
# 10                                NaN     NaN
# 11                                NaN     yes
# 12                                NaN     yes
# 13                                NaN     yes
# 14                                NaN     yes
# 15           Royal Engineers progress     NaN
# 16                 Wanderers progress     NaN
# 17        Hampstead Heathens progress     NaN
# 18                both teams progress     NaN
# 19               Queens Park progress     NaN
# 20               Queens Park progress     NaN
# 21                 Wanderers progress     NaN
# 22                                NaN     NaN
# 23                                NaN     NaN
# 24                                NaN     NaN
# 25                                NaN     NaN
# 26                                NaN     NaN
# 27                                NaN     NaN
# 28                                NaN     NaN
# 29                                NaN     NaN
# ...                               ...     ...
# 16446                             NaN     NaN
# 16447                             NaN     NaN
# 16448                             NaN     NaN
# 16449                             NaN     NaN
# 16450                             NaN     NaN
# 16451                             NaN     NaN
# 16452                             NaN     NaN
# 16453                             NaN     NaN
# 16454                             NaN     NaN
# 16455                             NaN     NaN
# 16456                             NaN     NaN
# 16457                             NaN     NaN
# 16458                             NaN     NaN
# 16459                             NaN     NaN
# 16460                             NaN     NaN
# 16461                             NaN     NaN
# 16462                             NaN     NaN
# 16463                             NaN     NaN
# 16464                             NaN     NaN
# 16465                             NaN     NaN
# 16466                             NaN     NaN
# 16467                             NaN     NaN
# 16468                             NaN     NaN
# 16469                             NaN     NaN
# 16470                             NaN     NaN
# 16471                             NaN     NaN
# 16472                             NaN     NaN
# 16473                             NaN     NaN
# 16474                             NaN     NaN
# 16475                             NaN     yes
#
# [16476 rows x 19 columns]

# %% [markdown]
# **Now plot the results**

# %%
#Initialize a figure, and use seaborn to plot
fig = sns.plt.figure()
y_av = movingaverage(season_tie["replay"], 8)
sns.plt.figure(1)
sns.plt.plot(season_tie["replay"])
sns.plt.plot(season_tie["initial"])
sns.plt.xlabel("Year")
sns.plt.ylabel("Number of Games")
sns.plt.legend(["Replays","First round Games"])
sns.plt.figure(2)
sns.plt.plot(season_tie["replay"].loc[1950:],'.--', linewidth = 1)
sns.plt.plot(season_tie.index[-65:-5],y_av[-65:-5], '-', color = 'b',linewidth = 2)
sns.plt.ylim([0,50])
sns.plt.xlabel("Year")
sns.plt.ylabel("Number of Games")
sns.plt.legend(["Replays", "10 year average"])

sns.plt.show()
fig.savefig("figures/replays.pdf")

# %% [markdown]
# ## Getting divisional information for clubs

# %%
#First note that there is a large discrepancy between the number of clubs in the top 4 divisions
#, and the number of clubs who play in the FA cup - this makes sense because ALL english clubs play
# in the FA cup, while fewer (only 142) have made it to league level

#Number of unique FA cup teams
print len(facup['home'].unique())
print len(facup['visitor'].unique())
#Number of unique teams in all english league cup games
print len(allgames['home'].unique())
print len(allgames['visitor'].unique())
# Out:
# 618
# 695
# 142
# 142

# %%
#Have a look at the allgames table
allgames.head(4)
# Out:
#          Date  Season             home           visitor   FT  hgoal  vgoal  \
# 0  1888-12-15    1888  Accrington F.C.       Aston Villa  1-1      1      1
# 1  1889-01-19    1888  Accrington F.C.  Blackburn Rovers  0-2      0      2
# 2  1889-03-23    1888  Accrington F.C.  Bolton Wanderers  2-3      2      3
# 3  1888-12-01    1888  Accrington F.C.           Burnley  5-1      5      1
#
#   division  tier  totgoal  goaldif result
# 0        1     1        2        0      D
# 1        1     1        2       -2      A
# 2        1     1        5       -1      A
# 3        1     1        6        4      H

# %%
#Now narrow down this table to only the unique instances of a team, its season and tier
# print allgames['tier'].unique()
# Gives answer [1,2,3,4]

#Because all clubs are represented in the home team column, we can narrow
#down the table to only include three columns
onlyranks = allgames[['Season','home','tier']]


#Now drop duplicate rows, i.e. every row of the table is now 
# a unique Season, Team and its league position for that season
onlyranks = onlyranks.drop_duplicates()
onlyranks = onlyranks.sort_values(by = ['home','Season'])


#Now do a merge on the season and home team
result = pd.merge(facup, onlyranks, how='left', on =['home','Season'])
result.rename(columns={'tier':'home_tier'}, inplace=True)


#Now repeat the merge for the visitor team, first doing some renaming
onlyranks.rename(columns={'home':'visitor'}, inplace=True)
facup_tiers = pd.merge(result, onlyranks, how = 'left', on = ['visitor','Season'])
facup_tiers.rename(columns={'tier':'visitor_tier'}, inplace=True)

#Now return the team name column to "home"
onlyranks.rename(columns={'visitor':'home'}, inplace=True)

# %% [markdown]
# ### Team's divisional position vs. time

# %%
#Next, visualize how a team has done over the years
team = 'York City'


fig = sns.plt.plot(onlyranks[onlyranks['home'] == team]['Season'], onlyranks[onlyranks['home'] == team]['tier'],'o-.')
sns.plt.ylim((4.5,0.5))
sns.plt.yticks([1,2,3,4], ["1st","2nd","3rd","4th"])
sns.axlabel("Season", "Division")
sns.plt.show()

# %% [markdown]
# ## Categorize games as upset or not

# %%
# Make a copy of the table above
facup2 = facup_tiers.copy()
#Remove illegitimate values
facup2.dropna(subset =['FT'],inplace = True)

#When a tier for a team isn't available, treat that team as Divison 5
facup2['home_tier'].fillna(5, inplace = True)
facup2['visitor_tier'].fillna(5, inplace = True)


#Define a function which calcualtes whether or not the lower division team won
def upset(htier,vtier,hgoal,vgoal):
    if (vtier == 1 and htier > vtier and hgoal > vgoal):
        #Visitor team in Div. 1, Home team in lower division, Home team wins
        return 'PU' #Premier league team was upset
    elif (htier == 1 and htier < vtier and hgoal < vgoal):
        return 'PU' 
    elif (htier < vtier and hgoal < vgoal):
        return 'U' #Lower Div team beat team in division above them
    elif (htier > vtier and hgoal > vgoal):
        return 'U'
    elif (htier != vtier and hgoal == vgoal and (htier == 1 or vtier ==1) ):
        return 'PD'#Lower Div team drew with Premier league team
    elif (htier != vtier and hgoal == vgoal):
        return 'D'
    else:
        return 'E'
    
def mismatch(htier,vtier):
    if (vtier == 1 and htier > vtier):
        return 'Lv1'
    elif (htier == 1 and vtier > htier):
        return '1vL'
    elif (htier < vtier):
        return 'Lvisit'
    elif (htier > vtier):
        return 'Lhome'
    else:
        return 'SameDiv'

def mismatchGoalDiff(interdiv,hgoal,vgoal):
    if (interdiv == 'Lv1' or interdiv == 'Lhome'):
        return hgoal - vgoal
    elif (interdiv == '1vL' or interdiv == 'Lvisit'):
        return vgoal - hgoal
    else:
        return hgoal - vgoal
    
    

#Create new columns detailing whether a game was indeed an upset
facup2['upset'] = facup2.apply(lambda row: upset(row['home_tier'], row['visitor_tier'],row['hgoal'],row['vgoal']), axis=1)
facup2['interdiv'] = facup2.apply(lambda row: mismatch(row['home_tier'], row['visitor_tier']), axis = 1)
facup2['LtierGoalDiff'] = facup2.apply(lambda row: mismatchGoalDiff(row['interdiv'], row['hgoal'],row['vgoal']), axis = 1)


#have a look at the new table
facup2[facup2['Season']==2014]
# Out:
#              date  Season                    home                 visitor  \
# 16323  2015-04-18    2014                 Reading                 Arsenal
# 16324  2015-04-19    2014             Aston Villa               Liverpool
# 16325  2015-03-07    2014           Bradford City                 Reading
# 16326  2015-03-07    2014             Aston Villa    West Bromwich Albion
# 16327  2015-03-08    2014               Liverpool        Blackburn Rovers
# 16328  2015-03-09    2014       Manchester United                 Arsenal
# 16329  2015-03-16    2014                 Reading           Bradford City
# 16330  2015-04-08    2014        Blackburn Rovers               Liverpool
# 16331  2015-02-14    2014    West Bromwich Albion         West Ham United
# 16332  2015-02-14    2014        Blackburn Rovers              Stoke City
# 16333  2015-02-14    2014            Derby County                 Reading
# 16334  2015-02-14    2014          Crystal Palace               Liverpool
# 16335  2015-02-15    2014             Aston Villa          Leicester City
# 16336  2015-02-15    2014           Bradford City              Sunderland
# 16337  2015-02-15    2014                 Arsenal           Middlesbrough
# 16338  2015-02-16    2014       Preston North End       Manchester United
# 16339  2015-01-23    2014        Cambridge United       Manchester United
# 16340  2015-01-24    2014        Blackburn Rovers            Swansea City
# 16341  2015-01-24    2014         Birmingham City    West Bromwich Albion
# 16342  2015-01-24    2014            Cardiff City                 Reading
# 16343  2015-01-24    2014                 Chelsea           Bradford City
# 16344  2015-01-24    2014            Derby County            Chesterfield
# 16345  2015-01-24    2014         Manchester City           Middlesbrough
# 16346  2015-01-24    2014       Preston North End        Sheffield United
# 16347  2015-01-24    2014              Sunderland                  Fulham
# 16348  2015-01-24    2014       Tottenham Hotspur          Leicester City
# 16349  2015-01-24    2014             Southampton          Crystal Palace
# 16350  2015-01-24    2014               Liverpool        Bolton Wanderers
# 16351  2015-01-25    2014            Bristol City         West Ham United
# 16352  2015-01-25    2014             Aston Villa         AFC Bournemouth
# ...           ...     ...                     ...                     ...
# 16446  2014-11-08    2014               Port Vale      Milton Keynes Dons
# 16447  2014-11-08    2014         Plymouth Argyle               AFC Fylde
# 16448  2014-11-08    2014                Barnsley           Burton Albion
# 16449  2014-11-08    2014       Hartlepool United    East Thurrock United
# 16450  2014-11-08    2014         Oldham Athletic           Leyton Orient
# 16451  2014-11-09    2014            Halifax Town           Bradford City
# 16452  2014-11-09    2014          Braintree Town            Chesterfield
# 16453  2014-11-09    2014              Portsmouth          Aldershot Town
# 16454  2014-11-09    2014       Stevenage Borough        Maidstone United
# 16455  2014-11-09    2014                 Wrexham                  Woking
# 16456  2014-11-09    2014           Coventry City          Worcester City
# 16457  2014-11-09    2014          Blyth Spartans              Altrincham
# 16458  2014-11-09    2014     Forest Green Rovers       Scunthorpe United
# 16459  2014-11-09    2014         Gosport Borough       Colchester United
# 16460  2014-11-09    2014           Norton United               Gateshead
# 16461  2014-11-09    2014            Notts County              Accrington
# 16462  2014-11-10    2014  Havant & Waterlooville       Preston North End
# 16463  2014-11-18    2014          Mansfield Town         Concord Rangers
# 16464  2014-11-18    2014       Weston-super-Mare        Doncaster Rovers
# 16465  2014-11-18    2014           AFC Wimbledon               York City
# 16466  2014-11-18    2014         Shrewsbury Town                 Walsall
# 16467  2014-11-18    2014              Accrington            Notts County
# 16468  2014-11-18    2014      AFC Telford United        Basingstoke Town
# 16469  2014-11-18    2014               Southport  Dagenham and Redbridge
# 16470  2014-11-18    2014        Sheffield United         Crewe Alexandra
# 16471  2014-11-18    2014                Rochdale        Northampton Town
# 16472  2014-11-19    2014          Aldershot Town              Portsmouth
# 16473  2014-11-20    2014        Maidstone United       Stevenage Borough
# 16474  2014-11-25    2014         Concord Rangers          Mansfield Town
# 16475  2015-05-30    2014                 Arsenal             Aston Villa
#
#         FT  hgoal  vgoal round      tie  aet      ...        \
# 16323  1-2      1      2     s  initial  yes      ...
# 16324  2-1      2      1     s  initial  NaN      ...
# 16325  0-0      0      0     6  initial  NaN      ...
# 16326  2-0      2      0     6  initial  NaN      ...
# 16327  0-0      0      0     6  initial  NaN      ...
# 16328  1-2      1      2     6  initial  NaN      ...
# 16329  3-0      3      0     6   replay  NaN      ...
# 16330  0-1      0      1     6   replay  NaN      ...
# 16331  4-0      4      0     5  initial  NaN      ...
# 16332  4-1      4      1     5  initial  NaN      ...
# 16333  1-2      1      2     5  initial  NaN      ...
# 16334  1-2      1      2     5  initial  NaN      ...
# 16335  2-1      2      1     5  initial  NaN      ...
# 16336  2-0      2      0     5  initial  NaN      ...
# 16337  2-0      2      0     5  initial  NaN      ...
# 16338  1-3      1      3     5  initial  NaN      ...
# 16339  0-0      0      0     4  initial  NaN      ...
# 16340  3-1      3      1     4  initial  NaN      ...
# 16341  1-2      1      2     4  initial  NaN      ...
# 16342  1-2      1      2     4  initial  NaN      ...
# 16343  2-4      2      4     4  initial  NaN      ...
# 16344  2-0      2      0     4  initial  NaN      ...
# 16345  0-2      0      2     4  initial  NaN      ...
# 16346  1-1      1      1     4  initial  NaN      ...
# 16347  0-0      0      0     4  initial  NaN      ...
# 16348  1-2      1      2     4  initial  NaN      ...
# 16349  2-3      2      3     4  initial  NaN      ...
# 16350  0-0      0      0     4  initial  NaN      ...
# 16351  0-1      0      1     4  initial  NaN      ...
# 16352  2-1      2      1     4  initial  NaN      ...
# ...    ...    ...    ...   ...      ...  ...      ...
# 16446  3-4      3      4     1  initial  NaN      ...
# 16447  2-0      2      0     1  initial  NaN      ...
# 16448  5-0      5      0     1  initial  NaN      ...
# 16449  2-0      2      0     1  initial  NaN      ...
# 16450  1-0      1      0     1  initial  NaN      ...
# 16451  1-2      1      2     1  initial  NaN      ...
# 16452  0-6      0      6     1  initial  NaN      ...
# 16453  2-2      2      2     1  initial  NaN      ...
# 16454  0-0      0      0     1  initial  NaN      ...
# 16455  3-0      3      0     1  initial  NaN      ...
# 16456  1-2      1      2     1  initial  NaN      ...
# 16457  4-1      4      1     1  initial  NaN      ...
# 16458  0-2      0      2     1  initial  NaN      ...
# 16459  3-6      3      6     1  initial  NaN      ...
# 16460  0-4      0      4     1  initial  NaN      ...
# 16461  0-0      0      0     1  initial  NaN      ...
# 16462  0-3      0      3     1  initial  NaN      ...
# 16463  1-1      1      1     1  initial  NaN      ...
# 16464  1-4      1      4     1  initial  NaN      ...
# 16465  3-1      3      1     1   replay  NaN      ...
# 16466  1-0      1      0     1   replay  NaN      ...
# 16467  2-1      2      1     1   replay  NaN      ...
# 16468  2-1      2      1     1   replay  NaN      ...
# 16469  2-0      2      0     1   replay  NaN      ...
# 16470  2-0      2      0     1   replay  NaN      ...
# 16471  2-1      2      1     1   replay  NaN      ...
# 16472  1-0      1      0     1   replay  NaN      ...
# 16473  2-1      2      1     1   replay  NaN      ...
# 16474  0-1      0      1     1   replay  NaN      ...
# 16475  4-0      4      0     f  initial  NaN      ...
#
#                        Venue attendance  nonmatch  notes neutral home_tier  \
# 16323  Wembley (new), London     84,081       NaN    NaN     yes         2
# 16324  Wembley (new), London     85,416       NaN    NaN     yes         1
# 16325                    NaN        NaN       NaN    NaN     NaN         3
# 16326                    NaN        NaN       NaN    NaN     NaN         1
# 16327                    NaN        NaN       NaN    NaN     NaN         1
# 16328                    NaN        NaN       NaN    NaN     NaN         1
# 16329                    NaN        NaN       NaN    NaN     NaN         2
# 16330                    NaN        NaN       NaN    NaN     NaN         2
# 16331                    NaN        NaN       NaN    NaN     NaN         1
# 16332                    NaN        NaN       NaN    NaN     NaN         2
# 16333                    NaN        NaN       NaN    NaN     NaN         2
# 16334                    NaN        NaN       NaN    NaN     NaN         1
# 16335                    NaN        NaN       NaN    NaN     NaN         1
# 16336                    NaN        NaN       NaN    NaN     NaN         3
# 16337                    NaN        NaN       NaN    NaN     NaN         1
# 16338                    NaN        NaN       NaN    NaN     NaN         3
# 16339                    NaN        NaN       NaN    NaN     NaN         4
# 16340                    NaN        NaN       NaN    NaN     NaN         2
# 16341                    NaN        NaN       NaN    NaN     NaN         2
# 16342                    NaN        NaN       NaN    NaN     NaN         2
# 16343                    NaN        NaN       NaN    NaN     NaN         1
# 16344                    NaN        NaN       NaN    NaN     NaN         2
# 16345                    NaN        NaN       NaN    NaN     NaN         1
# 16346                    NaN        NaN       NaN    NaN     NaN         3
# 16347                    NaN        NaN       NaN    NaN     NaN         1
# 16348                    NaN        NaN       NaN    NaN     NaN         1
# 16349                    NaN        NaN       NaN    NaN     NaN         1
# 16350                    NaN        NaN       NaN    NaN     NaN         1
# 16351                    NaN        NaN       NaN    NaN     NaN         3
# 16352                    NaN        NaN       NaN    NaN     NaN         1
# ...                      ...        ...       ...    ...     ...       ...
# 16446                    NaN        NaN       NaN    NaN     NaN         3
# 16447                    NaN        NaN       NaN    NaN     NaN         4
# 16448                    NaN        NaN       NaN    NaN     NaN         3
# 16449                    NaN        NaN       NaN    NaN     NaN         4
# 16450                    NaN        NaN       NaN    NaN     NaN         3
# 16451                    NaN        NaN       NaN    NaN     NaN         5
# 16452                    NaN        NaN       NaN    NaN     NaN         5
# 16453                    NaN        NaN       NaN    NaN     NaN         4
# 16454                    NaN        NaN       NaN    NaN     NaN         4
# 16455                    NaN        NaN       NaN    NaN     NaN         5
# 16456                    NaN        NaN       NaN    NaN     NaN         3
# 16457                    NaN        NaN       NaN    NaN     NaN         5
# 16458                    NaN        NaN       NaN    NaN     NaN         5
# 16459                    NaN        NaN       NaN    NaN     NaN         5
# 16460                    NaN        NaN       NaN    NaN     NaN         5
# 16461                    NaN        NaN       NaN    NaN     NaN         3
# 16462                    NaN        NaN       NaN    NaN     NaN         5
# 16463                    NaN        NaN       NaN    NaN     NaN         4
# 16464                    NaN        NaN       NaN    NaN     NaN         5
# 16465                    NaN        NaN       NaN    NaN     NaN         4
# 16466                    NaN        NaN       NaN    NaN     NaN         4
# 16467                    NaN        NaN       NaN    NaN     NaN         4
# 16468                    NaN        NaN       NaN    NaN     NaN         5
# 16469                    NaN        NaN       NaN    NaN     NaN         5
# 16470                    NaN        NaN       NaN    NaN     NaN         3
# 16471                    NaN        NaN       NaN    NaN     NaN         3
# 16472                    NaN        NaN       NaN    NaN     NaN         5
# 16473                    NaN        NaN       NaN    NaN     NaN         5
# 16474                    NaN        NaN       NaN    NaN     NaN         5
# 16475  Wembley (new), London     89,283       NaN    NaN     yes         1
#
#       visitor_tier upset interdiv  LtierGoalDiff
# 16323            1     E      Lv1             -1
# 16324            1     E  SameDiv              1
# 16325            2     D    Lhome              0
# 16326            1     E  SameDiv              2
# 16327            2    PD      1vL              0
# 16328            1     E  SameDiv             -1
# 16329            3     E   Lvisit             -3
# 16330            1     E      Lv1             -1
# 16331            1     E  SameDiv              4
# 16332            1    PU      Lv1              3
# 16333            2     E  SameDiv             -1
# 16334            1     E  SameDiv             -1
# 16335            1     E  SameDiv              1
# 16336            1    PU      Lv1              2
# 16337            2     E      1vL             -2
# 16338            1     E      Lv1             -2
# 16339            1    PD      Lv1              0
# 16340            1    PU      Lv1              2
# 16341            1     E      Lv1             -1
# 16342            2     E  SameDiv             -1
# 16343            3    PU      1vL              2
# 16344            3     E   Lvisit             -2
# 16345            2    PU      1vL              2
# 16346            3     E  SameDiv              0
# 16347            2    PD      1vL              0
# 16348            1     E  SameDiv             -1
# 16349            1     E  SameDiv             -1
# 16350            2    PD      1vL              0
# 16351            1     E      Lv1             -1
# 16352            2     E      1vL             -1
# ...            ...   ...      ...            ...
# 16446            3     E  SameDiv             -1
# 16447            5     E   Lvisit             -2
# 16448            4     E   Lvisit             -5
# 16449            5     E   Lvisit             -2
# 16450            3     E  SameDiv              1
# 16451            3     E    Lhome             -1
# 16452            3     E    Lhome             -6
# 16453            5     D   Lvisit              0
# 16454            5     D   Lvisit              0
# 16455            5     E  SameDiv              3
# 16456            5     U   Lvisit              1
# 16457            5     E  SameDiv              3
# 16458            3     E    Lhome             -2
# 16459            3     E    Lhome             -3
# 16460            5     E  SameDiv             -4
# 16461            4     D   Lvisit              0
# 16462            3     E    Lhome             -3
# 16463            5     D   Lvisit              0
# 16464            3     E    Lhome             -3
# 16465            4     E  SameDiv              2
# 16466            3     U    Lhome              1
# 16467            3     U    Lhome              1
# 16468            5     E  SameDiv              1
# 16469            4     U    Lhome              2
# 16470            3     E  SameDiv              2
# 16471            4     E   Lvisit             -1
# 16472            4     U    Lhome              1
# 16473            4     U    Lhome              1
# 16474            4     E    Lhome             -1
# 16475            1     E  SameDiv              4
#
# [153 rows x 24 columns]

# %%
#Clean up the table to include only 'relevant' columns, and now crosstabulate vs. season
facup2 = facup2[['date','Season','home','visitor','FT','hgoal','vgoal','round','tie','aet','home_tier','visitor_tier','upset','interdiv','LtierGoalDiff']]
upsets = pd.crosstab(index = facup2["Season"], columns = facup2["upset"])

# %% [markdown]
# # Plot of Number of upsets vs. years

# %%
#Finally print some data to show what we've done
#print grouped.head(20)

#Define a couple moving averages
y_av = movingaverage(upsets["U"], 5)
y2_av = movingaverage(upsets["PU"], 5)

initYear = 1950
diff = 2015 - initYear

fig = sns.plt.figure()
sns.plt.figure(1)
sns.color_palette("hls", 8)
#Plot the data
sns.plt.plot(upsets["U"].loc[initYear:],'.-' ,color = sns.xkcd_rgb["pale red"],linewidth = 0.5)
sns.plt.plot(upsets["PU"].loc[initYear:],'.-',color = sns.xkcd_rgb["dusty purple"], linewidth = 0.5)
sns.plt.plot(upsets.index[-diff:-5],y_av[-diff:-5],'-',color = 'r',linewidth = 2)
sns.plt.plot(upsets.index[-diff:-5],y2_av[-diff:-5],'-',color ='purple',linewidth = 2)
#Fiddle with the axes
sns.plt.xlabel("Year")
sns.plt.ylabel("Number of Games")
sns.plt.legend(["Lower Div. Team Won","Low Div. beat 1st div."], loc = 2)
fig.savefig("figures/wins.pdf")
fig = sns.plt.figure()


sns.plt.figure(2)

#Define a couple moving averages
y_av = movingaverage(upsets["D"], 5)
y2_av = movingaverage(upsets["PD"], 5)

#Now plot
sns.plt.plot(upsets["D"].loc[initYear:],'.-' ,color = sns.xkcd_rgb["pale red"],linewidth = 0.5)
sns.plt.plot(upsets["PD"].loc[initYear:],'.-',color = sns.xkcd_rgb["dusty purple"], linewidth = 0.5)
sns.plt.plot(upsets.index[-diff:-5],y_av[-diff:-5],'-',color = 'r',linewidth = 2)
sns.plt.plot(upsets.index[-diff:-5],y2_av[-diff:-5],'-',color ='purple',linewidth = 2)
#Fiddle with the axes
sns.plt.xlabel("Year")
sns.plt.ylabel("Number of Games")
sns.plt.legend(["Lower Div. Team Drew","Low Div. team drew with 1st div."], loc = 2)
fig.savefig("figures/draws.pdf")

sns.plt.show()

# %% [markdown]
# # Goal difference for lower division teams vs. 1st division teams

# %%
goalDiff = pd.pivot_table(facup2, values='LtierGoalDiff', index=['Season'], columns=['interdiv'], aggfunc=np.mean)
goalDiff.tail(50)
# Out:
# interdiv       1vL     Lhome       Lv1    Lvisit   SameDiv
# Season
# 1965     -1.600000 -0.193548 -0.250000 -1.500000  0.708333
# 1966     -2.333333 -0.571429 -0.500000 -1.763158  0.735849
# 1967     -1.560000 -0.297297 -0.550000 -1.500000  0.254902
# 1968     -1.333333 -0.608696 -0.523810 -1.852941  0.379310
# 1969     -1.625000 -0.236842 -0.473684 -1.095238  0.218182
# 1970     -1.700000  0.270270 -0.235294 -1.583333  0.576923
# 1971     -1.350000 -0.740741 -0.600000 -2.382353  0.316667
# 1972     -1.000000 -0.485714 -0.473684 -1.324324  0.433962
# 1973     -0.571429 -0.111111 -1.380952 -1.181818  0.265625
# 1974     -1.000000 -0.162162 -0.388889 -1.033333  0.491525
# 1975     -0.888889  0.000000  0.200000 -1.000000  0.553571
# 1976     -1.368421  0.029412 -0.076923 -1.309524  0.584615
# 1977     -1.900000  0.114286 -0.400000 -1.324324  0.851852
# 1978     -0.944444 -0.142857 -0.320000 -1.382353  0.457627
# 1979     -1.687500  0.068966 -0.160000 -1.129032  0.360656
# 1980     -1.764706 -0.400000 -0.714286 -1.256410  0.633803
# 1981     -0.642857 -0.230769  0.230769 -1.387097  0.222222
# 1982     -1.117647  0.034483 -0.133333 -1.595238  0.814815
# 1983     -1.666667 -0.575758 -0.227273 -1.256410  0.526316
# 1984     -1.952381 -0.176471 -0.952381 -1.272727  0.578947
# 1985     -1.800000 -0.172414 -0.526316 -1.428571  0.189655
# 1986     -1.944444  0.111111 -0.083333 -1.656250  0.611940
# 1987     -1.466667 -0.111111 -1.000000 -1.285714  0.107692
# 1988     -2.117647 -0.333333 -0.411765 -0.411765  0.315789
# 1989     -1.631579 -0.117647  0.038462 -1.090909  0.474576
# 1990     -1.400000 -0.321429  0.058824 -1.111111  0.454545
# 1991     -0.772727 -0.629630 -0.090909 -1.857143  0.518519
# 1992     -1.263158 -0.294118 -1.166667 -1.352941  0.086207
# 1993     -0.666667 -0.666667 -0.240000 -0.785714  0.152174
# 1994     -1.652174 -0.685714 -0.913043 -1.576923  0.403846
# 1995     -1.476190 -0.200000 -0.892857 -1.783784  0.428571
# 1996     -1.789474 -0.677419 -0.533333 -1.585366  0.311111
# 1997     -1.428571 -0.871795 -0.300000 -0.529412  0.360656
# 1998     -1.600000  0.000000 -1.214286 -1.685714  0.519231
# 1999     -1.157895 -0.516129 -0.352941 -1.078947  0.562500
# 2000     -1.333333 -0.200000 -1.333333 -1.181818  0.166667
# 2001     -1.222222 -0.189189 -1.000000 -1.138889  0.657895
# 2002     -1.000000 -0.923077 -0.538462 -1.444444  0.472727
# 2003     -1.071429  0.171429 -0.888889 -1.315789  0.188679
# 2004     -1.333333 -0.250000 -0.650000 -1.448276  0.229167
# 2005     -1.550000 -0.071429 -0.750000 -1.100000  0.196721
# 2006     -1.500000 -0.428571 -0.769231 -1.166667  0.035714
# 2007     -0.411765 -0.675676 -0.307692 -1.000000  0.235294
# 2008     -0.941176 -0.147059 -0.950000 -0.840000  0.350000
# 2009     -1.578947 -0.733333 -0.882353 -1.111111  0.827586
# 2010     -2.095238 -0.205882 -0.714286 -1.285714  0.421053
# 2011     -2.000000 -0.906250 -1.000000 -0.735294  0.607843
# 2012     -1.562500 -0.161290 -0.789474 -1.250000 -0.129630
# 2013     -1.375000 -0.384615 -0.666667 -1.371429  0.692308
# 2014     -0.875000 -0.275862 -1.000000 -1.033333  0.333333

# %%
#Define a couple moving averages
y_av = movingaverage(goalDiff["Lv1"], 5)
y2_av = movingaverage(goalDiff["1vL"], 5)
y3_av = movingaverage(goalDiff["SameDiv"], 5)

initYear = 1950
diff = 2015 - initYear

fig = sns.plt.figure()
sns.plt.figure(1)
sns.color_palette("hls", 8)
#Plot the data
sns.plt.plot(goalDiff["Lv1"].loc[initYear:],'.-' ,color = sns.xkcd_rgb["windows blue"],linewidth = 0.5)
sns.plt.plot(goalDiff["1vL"].loc[initYear:],'.-',color = sns.xkcd_rgb["grey"], linewidth = 0.5)
sns.plt.plot(goalDiff["SameDiv"].loc[initYear:],'.-',color = sns.xkcd_rgb["pale red"], linewidth = 0.5)
sns.plt.plot(goalDiff.index[-diff:-5],y_av[-diff:-5],'-',color = 'b',linewidth = 2)
sns.plt.plot(goalDiff.index[-diff:-5],y2_av[-diff:-5],'-',color ='black',linewidth = 2)
sns.plt.plot(goalDiff.index[-diff:-5],y3_av[-diff:-5],'-',color ='r',linewidth = 2)
#Fiddle with the axes
sns.plt.xlabel("Year")
sns.plt.ylabel("Goal difference (Lower Div- 1st Div)")
sns.plt.legend(["Lower Div vs. 1st div ","1st Div vs. Lower Div", "Baseline Home Goal Diff"], loc = 1)
sns.plt.ylim([-2.5,2])
fig.savefig("figures/goaldiff.pdf")
fig = sns.plt.figure()

# %% [markdown]
# # Composition of later rounds

# %%
#Count number of 1st, second and third+ division teams in each game
facup_unique = facup2[facup2['tie'] == 'initial' ]
facup_unique['count_1'] = (facup_unique['home_tier'] ==1).astype(int) + (facup_unique['visitor_tier'] ==1).astype(int)
facup_unique['count_2'] = (facup_unique['home_tier'] ==2).astype(int) + (facup_unique['visitor_tier'] ==2).astype(int)
facup_unique['count_3'] = (facup_unique['home_tier'] >2).astype(int) + (facup_unique['visitor_tier'] >2).astype(int)

#Now create a pivot table which summarizes the data
ans=pd.pivot_table(facup_unique, values=['count_1','count_2','count_3'], index=['Season'], columns=['round'], aggfunc=np.sum)
ans = ans.loc[1950:]
# Out:
# /Users/amaharaj/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/amaharaj/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amaharaj/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Set general plot properties
#sns.set_style("white")

sizes = {'4': 32, '5' :16, '6': 8, 's':4, 'f':2 }
mRound = '5'
fig = sns.plt.figure(figsize=(24, sizes[mRound]))
sns.plt.figure(1)
#sns.set_context({"figure.figsize": (24, sizes[mRound])})
#Plot 1 - background - "total" (top) series
sns.barplot(x = ans.index, y = ans['count_1'][mRound] + ans['count_2'][mRound] + ans['count_3'][mRound] , color = sns.xkcd_rgb["light grey"])

#Plot 2 - overlay - "middle" series
middle_plot = sns.barplot(x = ans.index, y = ans['count_2'][mRound] + ans['count_3'][mRound] ,color = sns.xkcd_rgb["windows blue"])

#Plot 3 - overlay - "bottom" series
bottom_plot = sns.barplot(x = ans.index, y = ans['count_3'][mRound] ,color = sns.xkcd_rgb["amber"])



topbar = plt.Rectangle((0,0),1,1,fc=sns.xkcd_rgb["greyish"], edgecolor = 'none')
middlebar = plt.Rectangle((0,0),1,1,fc=sns.xkcd_rgb["windows blue"],  edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc=sns.xkcd_rgb["amber"],  edgecolor = 'none')


l = plt.legend([bottombar, middlebar, topbar], ['3rd Division', '2nd Divison', '1st Division'], loc=1, ncol = 2, prop={'size':16})
l.draw_frame(False)

#Optional code - Make plot look nicer
sns.despine(left=True)
bottom_plot.set_ylabel("Number of teams")
bottom_plot.set_xlabel("Year")

bottom_plot.set(yticks=range(0,sizes[mRound]+1))


for item in bottom_plot.get_xticklabels():
    item.set_rotation(60)

#Set fonts to consistent 16pt size
for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
             bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
    item.set_fontsize(16)
    
plt.gcf().subplots_adjust(bottom=0.25)
fig.savefig("figures/5th_round.pdf")
fig = sns.plt.figure()

# %% [markdown]
# # View a team's performance over the years

# %%
team = 'Arsenal'
thisTeam = facup2[((facup2['home'] == team) | (facup2['visitor']== team ))]
thisTeam = thisTeam.drop(['upset','interdiv','LtierGoalDiff','lowerDivCount'], axis=1)
thisTeam = thisTeam.replace(to_replace = 's', value = 7)
thisTeam = thisTeam.replace(to_replace = 'f', value = 8)
thisTeam['round'] = pd.to_numeric(thisTeam['round'], errors='coerce')
thisTeam['Season'] = pd.to_numeric(thisTeam['Season'], errors='coerce')
progress = thisTeam.groupby(['Season']).max()
progress=progress.reset_index()



labels = []
for i in progress['Season']:
    if i%10 ==0 :
        labels.append(i)
    else:
        labels.append('')
    

sns.plt.figure(figsize=(20,5))
g=sns.barplot(x=progress['Season'],y=progress['round'])
g.set(yticklabels=['','1st','2nd','3rd','4th','5th','6th','SF','F'])
for item in g.get_xticklabels():
    item.set_rotation(60)

# %%
range(0,2)
# Out:
# [0, 1]
